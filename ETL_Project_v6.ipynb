# %% [markdown]
# ## ETL Project: TrueSafeCars.com
# Group 8 (NoFloods)
# * Roopa Patel
# * Samuel Parks
# * Steven Lee

# %%
import pandas as pd
import os
import numpy as np
import datetime
import requests
import json

# %% [markdown]
# ### EXTRACT Datasets

# %%
# Define our input datasets and load into dataframes
# NOTE: Cars1 refers to a dataset of cars that were scraped from TrueCar.com
#       Cars2 refers to a dataset of cars that were scraped from Craigslist

# Paths to our datasets
input_file_truecar = os.path.join(".", "Datasets", "true_car_listings.csv")
input_file_craigslist = os.path.join(".", "Datasets", "vehicles.csv")

# Read files into dataframes
truecar_df = pd.read_csv(input_file_truecar)
craigslist_df = pd.read_csv(input_file_craigslist)

# %%
# Output Preliminary statistics

# Row counts and unique VINs
print(f"TrueCar dataframe beginning number of rows: {truecar_df.shape[0]}")
total_true_car_VINs = len(truecar_df["Vin"].unique())
print(f"TrueCar total unique VIN records: {total_true_car_VINs}\n")

print(f"Craigslist dataframe beginning number of rows: {craigslist_df.shape[0]}")
total_craigslist_VINs = len(craigslist_df["vin"].unique())
print(f"Craigslist dataframe total unique VIN records: {total_craigslist_VINs}")
# Out:
# TrueCar dataframe beginning number of rows: 852122
# TrueCar total unique VIN records: 852075
#
# Craigslist dataframe beginning number of rows: 539759
# Craigslist dataframe total unique VIN records: 181678

# %%
# Counts by car make - TrueCar
truecar_grouped_by_make = truecar_df.groupby(['Make'])
truecar_count_by_make = truecar_grouped_by_make["Vin"].count()
truecar_count_by_make
# Out:
# Make
# AM                   19
# Acura             11049
# Alfa                 44
# Aston               149
# Audi              12618
# BMW               32415
# Bentley             367
# Buick             12491
# Cadillac          15047
# Chevrolet        102268
# Chrysler          16357
# Dodge             34368
# FIAT               1782
# Ferrari             345
# Fisker               19
# Ford             110432
# Freightliner         11
# GMC               29008
# Genesis             141
# Geo                   2
# HUMMER              949
# Honda             50193
# Hyundai           35837
# INFINITI          12258
# Isuzu                76
# Jaguar             2200
# Jeep              40373
# Kia               28636
# Lamborghini         121
# Land               4096
# Lexus             20641
# Lincoln            7120
# Lotus                42
# MINI               4375
# Maserati           1047
# Maybach              10
# Mazda             13365
# McLaren              47
# Mercedes-Benz     26323
# Mercury            1076
# Mitsubishi         4080
# Nissan            66250
# Oldsmobile          122
# Plymouth             51
# Pontiac            1783
# Porsche            4106
# Ram               19808
# Rolls-Royce          92
# Saab                260
# Saturn              963
# Scion              3043
# Subaru            16428
# Suzuki              334
# Tesla               231
# Toyota            77786
# Volkswagen        23249
# Volvo              5106
# smart               713
# Name: Vin, dtype: int64

# %%
# Counts by car make - Craigslist
craigslist_grouped_by_make = craigslist_df.groupby(['manufacturer'])
craigslist_count_by_make = craigslist_grouped_by_make["vin"].count()
craigslist_count_by_make
# Out:
# manufacturer
# acura               2371
# alfa-romeo            68
# aston-martin          20
# audi                3915
# bmw                 9135
# buick               4505
# cadillac            4737
# chevrolet          45185
# chrysler            4760
# datsun                25
# dodge              10599
# ferrari               45
# fiat                 645
# ford               58361
# gmc                14481
# harley-davidson      152
# hennessey              0
# honda              14042
# hyundai             8360
# infiniti            2755
# jaguar               642
# jeep               15592
# kia                 6323
# land rover             5
# lexus               3908
# lincoln             2009
# mazda               3785
# mercedes-benz       7405
# mercury              799
# mini                1563
# mitsubishi          1597
# morgan                 2
# nissan             17351
# pontiac             1488
# porche                 6
# ram                17325
# rover               1346
# saturn               810
# subaru              7004
# tesla                202
# toyota             23626
# volkswagen          6457
# volvo               1713
# Name: vin, dtype: int64

# %% [markdown]
# ### TRANSFORM Datasets

# %%
# Cleanup columns
#   1. Examine columns and remove unneeded columns
#   2. Rename columns to make the two datasets consistent
#   3. Reorder columns to make the two datasets consistent

# Print Before summary
print("---------------------------------")
print("BEFORE Column name cleanup:")
print("---------------------------------")
print("TrueCar dataframe columns:")
print(truecar_df.info())
print("\nCraigslist dataframe columns:")
print(craigslist_df.info())

# Drop unneeded columns
truecar_df.drop(['City'], axis=1, inplace=True)

# Drop unneeded columns
craigslist_df.drop(['id', 'url', 'region', 'region_url', 'cylinders',\
                    'fuel', 'title_status', 'transmission', 'drive',\
                    'size', 'type', 'paint_color', 'image_url',\
                    'description', 'county', 'lat', 'long'], axis=1, inplace=True)

# Add Condition column to TrueCar dataframe, used later so we can concatentate the two dataframes 
truecar_df["Condition"] = ""

# Rename Craigslist columns to be consistent with TrueCar
craigslist_df.rename(columns={"price" : "Price",
                              "year" : "Year",
                              "manufacturer" : "Make",
                              "model" : "Model",
                              "condition" : "Condition",
                              "odometer" : "Mileage",
                              "vin" : "Vin",
                              "state" : "State"}, inplace=True)

# Reorganize Craigslist columns to match cars1
craigslist_df = craigslist_df[["Price", "Year", "Mileage", "State", "Vin", "Make", "Model", "Condition"]]

# Print After summary
print("\n---------------------------------")
print("AFTER Column name cleanup:")
print("---------------------------------")
print("TrueCar dataframe columns:")
print(truecar_df.info())
print("\nCraigslist dataframe columns:")
print(craigslist_df.info())
# Out:
# ---------------------------------
# BEFORE Column name cleanup:
# ---------------------------------
# TrueCar dataframe columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852122 entries, 0 to 852121
# Data columns (total 8 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Price    852122 non-null  int64
#  1   Year     852122 non-null  int64
#  2   Mileage  852122 non-null  int64
#  3   City     852122 non-null  object
#  4   State    852122 non-null  object
#  5   Vin      852122 non-null  object
#  6   Make     852122 non-null  object
#  7   Model    852122 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 52.0+ MB
# None
#
# Craigslist dataframe columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539759 entries, 0 to 539758
# Data columns (total 25 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            539759 non-null  int64
#  1   url           539759 non-null  object
#  2   region        539759 non-null  object
#  3   region_url    539759 non-null  object
#  4   price         539759 non-null  int64
#  5   year          538772 non-null  float64
#  6   manufacturer  516175 non-null  object
#  7   model         531746 non-null  object
#  8   condition     303707 non-null  object
#  9   cylinders     321264 non-null  object
#  10  fuel          536366 non-null  object
#  11  odometer      440783 non-null  float64
#  12  title_status  536819 non-null  object
#  13  transmission  535786 non-null  object
#  14  vin           315349 non-null  object
#  15  drive         383987 non-null  object
#  16  size          168550 non-null  object
#  17  type          392290 non-null  object
#  18  paint_color   365520 non-null  object
#  19  image_url     539740 non-null  object
#  20  description   539738 non-null  object
#  21  county        0 non-null       float64
#  22  state         539759 non-null  object
#  23  lat           530785 non-null  float64
#  24  long          530785 non-null  float64
# dtypes: float64(5), int64(2), object(18)
# memory usage: 103.0+ MB
# None
#
# ---------------------------------
# AFTER Column name cleanup:
# ---------------------------------
# TrueCar dataframe columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852122 entries, 0 to 852121
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Price      852122 non-null  int64
#  1   Year       852122 non-null  int64
#  2   Mileage    852122 non-null  int64
#  3   State      852122 non-null  object
#  4   Vin        852122 non-null  object
#  5   Make       852122 non-null  object
#  6   Model      852122 non-null  object
#  7   Condition  852122 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 52.0+ MB
# None
#
# Craigslist dataframe columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539759 entries, 0 to 539758
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Price      539759 non-null  int64
#  1   Year       538772 non-null  float64
#  2   Mileage    440783 non-null  float64
#  3   State      539759 non-null  object
#  4   Vin        315349 non-null  object
#  5   Make       516175 non-null  object
#  6   Model      531746 non-null  object
#  7   Condition  303707 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.9+ MB
# None

# %% [markdown]
# ##### NOTE:
# * At this time, we could concatenate the two dataframes.
# * However, we want to later choose random sets of rows for testing and production from each dataset.
# * The main reason for this is to reduce the number of API calls.

# %%
# Cleanup data in columns that have text
#   1. Remove any whitespace (trim or strip) from string values
#   2. Capitalize values in these text columns consistently
#   3. Replace any NaNs in the Condition column with the text "Unknown"

# Strip any whitespace from strings
truecar_df["State"] = truecar_df["State"].str.strip()
truecar_df["Vin"] = truecar_df["Vin"].str.strip()
truecar_df["Make"] = truecar_df["Make"].str.strip()
truecar_df["Model"] = truecar_df["Model"].str.strip()
truecar_df["Condition"] = truecar_df["Condition"].str.strip()

craigslist_df["State"] = craigslist_df["State"].str.strip()
craigslist_df["Vin"] = craigslist_df["Vin"].str.strip()
craigslist_df["Make"] = craigslist_df["Make"].str.strip()
craigslist_df["Model"] = craigslist_df["Model"].str.strip()
craigslist_df["Condition"] = craigslist_df["Condition"].str.strip()

# Capitalize values in these text columns consistently
truecar_df["Make"] = truecar_df["Make"].str.title()
truecar_df["Model"] = truecar_df["Model"].str.title()
truecar_df["Condition"] = truecar_df["Condition"].str.title()
truecar_df["State"] = truecar_df["State"].str.upper()

craigslist_df["Make"] = craigslist_df["Make"].str.title()
craigslist_df["Model"] = craigslist_df["Model"].str.title()
craigslist_df["Condition"] = craigslist_df["Condition"].str.title()
craigslist_df["State"] = craigslist_df["State"].str.upper()

# Replace the NaNs in Condition with Unknown
craigslist_df.loc[craigslist_df["Condition"].isnull(),"Condition"] = "Unknown"

# %%
# Find problem rows for each dataset.  These are records with NaNs in any of the columns
#   1. Find rows with NaNs
#   2. If NaNs are found, extract these rows as CSVs for separate analysis by the client
#   3. Remove these rows from our dataframes

# Paths to our output files
truecar_problem_records = os.path.join(".", "ClientAnalysisNeeded", "truecar_problems.csv")
craigslist_problem_records = os.path.join(".", "ClientAnalysisNeeded", "craigslist_problems.csv")

# Find rows with NaNs in TrueCar dataset
truecar_is_NaN = truecar_df.isnull()
truecar_row_has_NaN = truecar_is_NaN.any(axis=1)
truecar_rows_with_NaN = truecar_df[truecar_row_has_NaN]

# Find rows with NaNs in Craigslist dataset
craigslist_is_NaN = craigslist_df.isnull()
craigslist_row_has_NaN = craigslist_is_NaN.any(axis=1)
craigslist_rows_with_NaN = craigslist_df[craigslist_row_has_NaN]

# If problems exist, create CSV file then remove the problem records from the dataset
print(f"Number of TrueCar problem rows found: {truecar_rows_with_NaN.shape[0]}")
if truecar_rows_with_NaN.shape[0] > 0:
    print(f"    Number of TrueCar rows BEFORE removing problem rows: {truecar_df.shape[0]}")
    truecar_rows_with_NaN.to_csv(truecar_problem_records, header=True)
    problem_index_vals = list(truecar_rows_with_NaN.index.values)
    truecar_df = truecar_df.loc[~truecar_df.index.isin(problem_index_vals), :]
    print(f"    Number of TrueCar rows AFTER removing problem rows: {truecar_df.shape[0]}")
    
print(f"Number of Craigslist problem rows found: {craigslist_rows_with_NaN.shape[0]}")    
if craigslist_rows_with_NaN.shape[0] > 0:
    print(f"    Number of Craigslist rows BEFORE removing problem rows: {craigslist_df.shape[0]}")
    craigslist_rows_with_NaN.to_csv(craigslist_problem_records, header=True)
    problem_index_vals = list(craigslist_rows_with_NaN.index.values)
    craigslist_df = craigslist_df.loc[~craigslist_df.index.isin(problem_index_vals), :]
    print(f"    Number of Craigslist rows AFTER removing problem rows: {craigslist_df.shape[0]}")
# Out:
# Number of TrueCar problem rows found: 0
# Number of Craigslist problem rows found: 248071
#     Number of Craigslist rows BEFORE removing problem rows: 539759
#     Number of Craigslist rows AFTER removing problem rows: 291688

# %%
# Find and process duplicate VINs
#   1. Find duplicate VIN records
#   2. If duplicate VINs are found, extract these rows as CSVs for separate analysis by the client
#   3. Remove these rows from our dataframes

# Paths to our output files
truecar_dup_vins = os.path.join(".", "ClientAnalysisNeeded", "truecar_dup_vins.csv")
craigslist_dup_vins = os.path.join(".", "ClientAnalysisNeeded", "craigslist_dup_vins.csv")

# For Truecar
truecar_duplicateVinRows = truecar_df[truecar_df.duplicated(["Vin"])]
print(f"Number of TrueCar duplicate VINs found: {truecar_duplicateVinRows.shape[0]}")
if truecar_duplicateVinRows.shape[0] > 0:
    print(f"    Number of TrueCar rows BEFORE removing duplicate VINs: {truecar_df.shape[0]}")
    truecar_duplicateVinRows.to_csv(truecar_dup_vins, header=True)
    
    dup_vins_index_vals = list(truecar_duplicateVinRows.index.values)
    truecar_df = truecar_df.loc[~truecar_df.index.isin(dup_vins_index_vals), :]
    print(f"    Number of TrueCar rows AFTER removing duplicate VINs: {truecar_df.shape[0]}")

# For Craigslist
craigslist_duplicateVinRows = craigslist_df[craigslist_df.duplicated(["Vin"])]
print(f"Number of Craigslist duplicate VINs found: {craigslist_duplicateVinRows.shape[0]}")
if craigslist_duplicateVinRows.shape[0] > 0:
    print(f"    Number of Craigslist rows BEFORE removing duplicate VINs: {craigslist_df.shape[0]}")
    craigslist_duplicateVinRows.to_csv(craigslist_dup_vins, header=True)
    
    dup_vins_index_vals = list(craigslist_duplicateVinRows.index.values)
    craigslist_df = craigslist_df.loc[~craigslist_df.index.isin(dup_vins_index_vals), :]
    print(f"    Number of Craigslist rows AFTER removing duplicate VINs: {craigslist_df.shape[0]}")
# Out:
# Number of TrueCar duplicate VINs found: 47
#     Number of TrueCar rows BEFORE removing duplicate VINs: 852122
#     Number of TrueCar rows AFTER removing duplicate VINs: 852075
# Number of Craigslist duplicate VINs found: 122626
#     Number of Craigslist rows BEFORE removing duplicate VINs: 291688
#     Number of Craigslist rows AFTER removing duplicate VINs: 169062

# %%
# Ensure datatypes are consistent across the two datasets
# Need to convert Craigslist "Year" and "Mileage" columns from float64 to int64

# Define conversion dictionary
conversion_dict = {"Year" : "int64",
                   "Mileage" : "int64"}

# Make the conversion
craigslist_df = craigslist_df.astype(conversion_dict)

# Confirm conversion
craigslist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169062 entries, 0 to 539733
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Price      169062 non-null  int64
#  1   Year       169062 non-null  int64
#  2   Mileage    169062 non-null  int64
#  3   State      169062 non-null  object
#  4   Vin        169062 non-null  object
#  5   Make       169062 non-null  object
#  6   Model      169062 non-null  object
#  7   Condition  169062 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 11.6+ MB

# %%
# Create Sales Channel column and populate
#   - Create column based on the "Year" column
#   - If the car is >= 20 years old, then the sales channel should be "Auction",
#   - otherwise the sales channel should be "Public"

# Get current year
current_datetime = datetime.datetime.now()
current_year = current_datetime.year

# Define Public vs Auction threshold
public_vs_auction_threshold = 20

# Define function to determine Auction vs Public based on current year
def sales_or_auction(row):
    if (current_year - row["Year"] >= public_vs_auction_threshold):
        val = "Auction"
    else:
        val = "Public"
    return val

# Apply function to the TrueCar dataset
temp = truecar_df.copy()
truecar_df = temp.copy()
truecar_df["Sales_Channel"] = truecar_df.apply(sales_or_auction, axis=1)

# Apply function to the Craigslist dataset
temp = craigslist_df.copy()
craigslist_df = temp.copy()
craigslist_df["Sales_Channel"] = craigslist_df.apply(sales_or_auction, axis=1)

# Get counts by sales channel for TrueCar
truecar_sales_gb = truecar_df.groupby("Sales_Channel").count()
print("TrueCar VIN count by sales channel:")
print(truecar_sales_gb["Vin"])

# Get counts by sales channel for Craigslist
craigslist_sales_gb = craigslist_df.groupby("Sales_Channel").count()
print("\nCraigslist VIN count by sales channel:")
print(craigslist_sales_gb["Vin"])
# Out:
# TrueCar VIN count by sales channel:
# Sales_Channel
# Auction      4557
# Public     847518
# Name: Vin, dtype: int64
#
# Craigslist VIN count by sales channel:
# Sales_Channel
# Auction      6233
# Public     162829
# Name: Vin, dtype: int64

# %%
# Update sales channel based on Condition (applies to the Craigslist dataset only)

# Define a list of Conditions that qualify for the Public sales channel
# Anything not in this list will be assigned to the Auction sales channel
public_sales_conditions = ["New", "Excellent", "Like New", "Good", "Unknown"]

craigslist_df.loc[~craigslist_df['Condition'].isin(public_sales_conditions),"Sales_Channel"] = "Auction"
craigslist_sales_gb = craigslist_df.groupby("Sales_Channel").count()
print("\nCraigslist VIN count by sales channel after updated based on condition:")
print(craigslist_sales_gb["Vin"])
# Out:
# Craigslist VIN count by sales channel after updated based on condition:
# Sales_Channel
# Auction      7360
# Public     161702
# Name: Vin, dtype: int64

# %% [markdown]
# ### CREATE Test and Production Dataframes

# %%
# Create Test and Production dataframes by randomly selecting from our main dataframes
# Create CSV output for dataframes

# Declare output files
truecar_test_file = os.path.join(".", "TrimmedDatasets", "truecar_test_data.csv")
truecar_prod_file = os.path.join(".", "TrimmedDatasets", "truecar_prod_data.csv")
craigslist_test_file = os.path.join(".", "TrimmedDatasets", "craigslist_test_data.csv")
craigslist_prod_file = os.path.join(".", "TrimmedDatasets", "craigslist_prod_data.csv")

# Declare our sizes for Test and Production dataframe
test_dataframe_size = 50
prod_dataframe_size = 250


# Create TrueCar Test and Production dataframes
truecar_random_index = np.random.choice(truecar_df.shape[0], replace=False, size=test_dataframe_size)
truecar_test_df = truecar_df.iloc[truecar_random_index]

truecar_random_index = np.random.choice(truecar_df.shape[0], replace=False, size=prod_dataframe_size)
truecar_prod_df = truecar_df.iloc[truecar_random_index]


# Create Craigslist Test and Production dataframes
craigslist_random_index = np.random.choice(craigslist_df.shape[0], replace=False, size=test_dataframe_size)
craigslist_test_df = craigslist_df.iloc[craigslist_random_index]

craigslist_random_index = np.random.choice(craigslist_df.shape[0], replace=False, size=prod_dataframe_size)
craigslist_prod_df = craigslist_df.iloc[craigslist_random_index]


# Output dataframes as CSVs
truecar_test_df.to_csv(truecar_test_file, header=True)
truecar_prod_df.to_csv(truecar_prod_file, header=True)
craigslist_test_df.to_csv(craigslist_test_file, header=True)
craigslist_prod_df.to_csv(craigslist_prod_file, header=True)

# %%
# Create merged Test and Production dataframes
# Create CSV output for combined dataframes

# Declare output files
comb_test_file = os.path.join(".", "TrimmedDatasets", "combined_test_data.csv")
comb_prod_file = os.path.join(".", "TrimmedDatasets", "combined_prod_data.csv")

# Perform concatentations
comb_test_df = pd.concat([truecar_test_df, craigslist_test_df], ignore_index=True)
comb_prod_df = pd.concat([truecar_prod_df, craigslist_prod_df], ignore_index=True)

# Output dataframes as CSVs
comb_test_df.to_csv(comb_test_file, header=True)
comb_prod_df.to_csv(comb_prod_file, header=True)

# %% [markdown]
# ### NHTSA.GOV API Call - Obtain Clean Make and Model
# Note: Due to the volume of cars in our database, we will be limiting tasks that involve API calls
# to a subset of our dataset

# %%
# Use NHTSA VIN Decoder API to get a clean Make and Model for the Recall API calls 
# NOTE: VIN DECODER ONLY WORKS FOR YEARS 1981 AND NEWER
#       FOR INVALID VINs, THE DECODER WILL HAVE ["Results"][0]["ErrorCode"] != 0
#       FOR VALID VINs, THE DECODER WILL HAVE ["Results"][0]["ErrorCode"] = 0

vin_base_url = "https://vpic.nhtsa.dot.gov/api/vehicles/decodevinvalues/"
earliest_valid_year = 1981

# Create column to indicate whether VIN has been verified or not
comb_test_df["Vin_Verified"] = False

# Iterate through dataframe
for index, row in comb_test_df.iterrows(): 
    if row["Year"] >= earliest_valid_year:
        # Form query URL for current Vin and Year
        current_vin = row["Vin"]
        current_year = row["Year"]
        vin_query_url = f"{vin_base_url}{current_vin}?format=json&modelyear={current_year}"

        # Make API call
        response = requests.get(vin_query_url).json()

        # Check response object
        response_code = response["Results"][0]["ErrorCode"]
        if (response_code == "0"):
            # Successful response
            # Set Vin Verified to True
            comb_test_df.loc[index, "Vin_Verified"] = True

            # Update Make and Model from API call results
            comb_test_df.loc[index, "Make"]  = response["Results"][0]["Make"]
            comb_test_df.loc[index, "Model"] = response["Results"][0]["Model"]

# %% [markdown]
# ### NHTSA.GOV API Call - Obtain Recall Data
# Note: Due to the volume of cars in our database, we will be limiting tasks that involve API calls
# to a subset of our dataset

# %%
try:
  print(x)
except NameError:
  print("Variable x is not defined")
except:
  print("Something else went wrong")

# %%
# Use NHTSA Recall API to get recall information for each Vin Verified row of our dataframe

recall_base_url = f"https://one.nhtsa.gov/webapi/api/Recalls/vehicle/"

# Iterate through dataframe
for index, row in comb_test_df.iterrows(): 
    if row["Vin_Verified"] == True:
        # Only make Recall API calls for Vin Verified rows
        
        # Form query URL for current Year, Make, and Model
        current_year = row["Year"]
        current_make = row["Make"]
        current_model = row["Model"]
        current_vin = row["Vin"]

        recall_query_url = f"{recall_base_url}modelyear/{current_year}/make/{current_make}/model/{current_model}?format=json"

        try:
            # Make API call and store response
            response = requests.get(recall_query_url).json()

            if (response["Count"] > 0):
                # Recall data found
                current_recall_dict = {}
                current_recall_lst = []
                for x in range(response["Count"]):
                    current_recall_dict = {"NHTSACampaignNumber" : response["Results"][x]["NHTSACampaignNumber"]}

                    current_recall_lst.append(current_recall_dict)

                print(f"Recall data for: {current_vin} {current_year} {current_make} {current_model}:")
                print(current_recall_lst)
                print("-------------------------------------------------------")
        except json.decoder.JSONDecodeError:
            print("-------------------------------------------------------")
            print(f"JSON Decode error occurred for: {current_vin} {current_year} {current_make} {current_model}:")
            print("-------------------------------------------------------")
        except:
            print("-------------------------------------------------------")
            print(f"Other error occurred for: {current_vin} {current_year} {current_make} {current_model}:")
            print("-------------------------------------------------------")
# Out:
# Recall data for: 2FMHK6DT0ABA38716 2010 FORD Flex:
# [{'NHTSACampaignNumber': '16V247000'}]
# -------------------------------------------------------
# Recall data for: 1GBFG15R211220159 2001 CHEVROLET Express:
# [{'NHTSACampaignNumber': '08V649000'}, {'NHTSACampaignNumber': '08V650000'}]
# -------------------------------------------------------
# Recall data for: WVGWV7AX2HK016499 2017 VOLKSWAGEN Tiguan:
# [{'NHTSACampaignNumber': '16V955000'}, {'NHTSACampaignNumber': '18V102000'}, {'NHTSACampaignNumber': '18V329000'}]
# -------------------------------------------------------
# Recall data for: 1N6AA1F23HN503727 2017 NISSAN Titan:
# [{'NHTSACampaignNumber': '17V268000'}, {'NHTSACampaignNumber': '18V240000'}, {'NHTSACampaignNumber': '19V495000'}]
# -------------------------------------------------------
# Recall data for: 1G6AA5RA9G0197693 2016 CADILLAC ATS:
# [{'NHTSACampaignNumber': '15V558000'}, {'NHTSACampaignNumber': '15V463000'}]
# -------------------------------------------------------
# Recall data for: 1N4AL3AP2EC130625 2014 NISSAN Altima:
# [{'NHTSACampaignNumber': '14V138000'}, {'NHTSACampaignNumber': '15V116000'}, {'NHTSACampaignNumber': '15V486000'}, {'NHTSACampaignNumber': '15V681000'}, {'NHTSACampaignNumber': '16V029000'}, {'NHTSACampaignNumber': '16V244000'}, {'NHTSACampaignNumber': '16V911000'}]
# -------------------------------------------------------
# Recall data for: 1G1PE5SB4G7105064 2016 CHEVROLET Cruze:
# [{'NHTSACampaignNumber': '16V498000'}, {'NHTSACampaignNumber': '16V502000'}, {'NHTSACampaignNumber': '17V057000'}, {'NHTSACampaignNumber': '18V304000'}]
# -------------------------------------------------------
# Recall data for: 5TDDY5G13ES094224 2014 TOYOTA Sequoia:
# [{'NHTSACampaignNumber': '17V311000'}]
# -------------------------------------------------------
# Recall data for: 2LMDJ8JK2DBL29882 2013 LINCOLN MKX:
# [{'NHTSACampaignNumber': '14V393000'}]
# -------------------------------------------------------
# Recall data for: 2FMDK4JC5CBA35885 2012 FORD Edge:
# [{'NHTSACampaignNumber': '12V438000'}, {'NHTSACampaignNumber': '14V002000'}, {'NHTSACampaignNumber': '14V393000'}]
# -------------------------------------------------------
# Recall data for: 2G4WD582481144423 2008 BUICK LaCrosse:
# [{'NHTSACampaignNumber': '14V355000'}, {'NHTSACampaignNumber': '15V519000'}]
# -------------------------------------------------------
# Recall data for: 2G1WB5E36C1145095 2012 CHEVROLET Impala:
# [{'NHTSACampaignNumber': '11V398000'}, {'NHTSACampaignNumber': '12V377000'}, {'NHTSACampaignNumber': '14V355000'}]
# -------------------------------------------------------
# Recall data for: 3N63M0YN0HK694675 2017 CHEVROLET City Express:
# [{'NHTSACampaignNumber': '18V551000'}]
# -------------------------------------------------------
# Recall data for: 5FNRL5H43GB168472 2016 HONDA Odyssey:
# [{'NHTSACampaignNumber': '16V417000'}, {'NHTSACampaignNumber': '16V932000'}, {'NHTSACampaignNumber': '16V933000'}, {'NHTSACampaignNumber': '17V725000'}, {'NHTSACampaignNumber': '18V170000'}]
# -------------------------------------------------------
# Recall data for: 5TDKK3DC2BS049273 2011 TOYOTA Sienna:
# [{'NHTSACampaignNumber': '10V036000'}, {'NHTSACampaignNumber': '10V620000'}, {'NHTSACampaignNumber': '11V306000'}, {'NHTSACampaignNumber': '11V560000'}, {'NHTSACampaignNumber': '11V566000'}, {'NHTSACampaignNumber': '13V014000'}, {'NHTSACampaignNumber': '13V123000'}, {'NHTSACampaignNumber': '14V273000'}, {'NHTSACampaignNumber': '14V743000'}, {'NHTSACampaignNumber': '16V340000'}, {'NHTSACampaignNumber': '16V396000'}, {'NHTSACampaignNumber': '16V858000'}, {'NHTSACampaignNumber': '19V005000'}, {'NHTSACampaignNumber': '19V741000'}]
# -------------------------------------------------------
# Recall data for: 1J8GW58S13C621534 2003 JEEP Grand Cherokee:
# [{'NHTSACampaignNumber': '06E022000'}, {'NHTSACampaignNumber': '06E023000'}, {'NHTSACampaignNumber': '06E011000'}, {'NHTSACampaignNumber': '06E064000'}, {'NHTSACampaignNumber': '06V197000'}, {'NHTSACampaignNumber': '09E012000'}, {'NHTSACampaignNumber': '09E025000'}, {'NHTSACampaignNumber': '09V117000'}, {'NHTSACampaignNumber': '12V527000'}, {'NHTSACampaignNumber': '15V046000'}]
# -------------------------------------------------------
# Recall data for: JF2SJADC5GH454418 2016 SUBARU Forester:
# [{'NHTSACampaignNumber': '16V162000'}, {'NHTSACampaignNumber': '19V149000'}, {'NHTSACampaignNumber': '19V701000'}]
# -------------------------------------------------------
# Recall data for: 1ZVBP8AM9C5206782 2012 FORD Mustang:
# [{'NHTSACampaignNumber': '12V190000'}, {'NHTSACampaignNumber': '15V319000'}, {'NHTSACampaignNumber': '16V248000'}, {'NHTSACampaignNumber': '17V024000'}, {'NHTSACampaignNumber': '19V001000'}, {'NHTSACampaignNumber': '19V001000'}]
# -------------------------------------------------------
# Recall data for: 5TFJU4GN8EX051990 2014 TOYOTA Tacoma:
# [{'NHTSACampaignNumber': '13V557000'}, {'NHTSACampaignNumber': '14V475000'}, {'NHTSACampaignNumber': '14V828000'}, {'NHTSACampaignNumber': '17V425000'}]
# -------------------------------------------------------
# Recall data for: 3FA6P0LU4DR202498 2013 FORD Fusion:
# [{'NHTSACampaignNumber': '12V551000'}, {'NHTSACampaignNumber': '12V553000'}, {'NHTSACampaignNumber': '13V232000'}, {'NHTSACampaignNumber': '13V227000'}, {'NHTSACampaignNumber': '14V164000'}, {'NHTSACampaignNumber': '14V597000'}, {'NHTSACampaignNumber': '15V246000'}, {'NHTSACampaignNumber': '15V250000'}, {'NHTSACampaignNumber': '16V875000'}, {'NHTSACampaignNumber': '17V209000'}, {'NHTSACampaignNumber': '17V210000'}, {'NHTSACampaignNumber': '18V169000'}, {'NHTSACampaignNumber': '18V471000'}, {'NHTSACampaignNumber': '19V362000'}, {'NHTSACampaignNumber': '19V632000'}]
# -------------------------------------------------------
# Recall data for: 1FT7W2BT1FEC10974 2015 FORD F-250:
# [{'NHTSACampaignNumber': '19V401000'}]
# -------------------------------------------------------
# Recall data for: JM3KE4DYXF0539615 2015 MAZDA CX-5:
# [{'NHTSACampaignNumber': '16E002000'}, {'NHTSACampaignNumber': '16V064000'}, {'NHTSACampaignNumber': '16V203000'}, {'NHTSACampaignNumber': '16V644000'}]
# -------------------------------------------------------
# Recall data for: 4T1BF1FK0EU339438 2014 TOYOTA Camry:
# [{'NHTSACampaignNumber': '13V505000'}, {'NHTSACampaignNumber': '14V715000'}, {'NHTSACampaignNumber': '14V576000'}]
# -------------------------------------------------------
# Recall data for: JTMBFREV5FJ013443 2015 TOYOTA RAV4:
# [{'NHTSACampaignNumber': '15V011000'}, {'NHTSACampaignNumber': '14V828000'}, {'NHTSACampaignNumber': '15V144000'}]
# -------------------------------------------------------
# Recall data for: 5TFEY5F19FX175648 2015 TOYOTA Tundra:
# [{'NHTSACampaignNumber': '15V315000'}, {'NHTSACampaignNumber': '16V420000'}, {'NHTSACampaignNumber': '17V311000'}]
# -------------------------------------------------------
# Recall data for: 1FTEX1CF8GKE64885 2016 FORD F-150:
# [{'NHTSACampaignNumber': '20V098000'}, {'NHTSACampaignNumber': '16V110000'}, {'NHTSACampaignNumber': '16V475000'}, {'NHTSACampaignNumber': '17V331000'}, {'NHTSACampaignNumber': '17V526000'}, {'NHTSACampaignNumber': '17V652000'}, {'NHTSACampaignNumber': '17V767000'}, {'NHTSACampaignNumber': '18V568000'}, {'NHTSACampaignNumber': '18V894000'}, {'NHTSACampaignNumber': '19V278000'}]
# -------------------------------------------------------
# Recall data for: 1HGCR2F36FA071210 2015 HONDA Accord:
# [{'NHTSACampaignNumber': '15V121000'}, {'NHTSACampaignNumber': '17V418000'}, {'NHTSACampaignNumber': '19V060000'}]
# -------------------------------------------------------
# Recall data for: 1FMHK7F89BGA76289 2011 FORD Explorer:
# [{'NHTSACampaignNumber': '11V063000'}, {'NHTSACampaignNumber': '14E001000'}, {'NHTSACampaignNumber': '14V286000'}, {'NHTSACampaignNumber': '15V171000'}, {'NHTSACampaignNumber': '17E048000'}, {'NHTSACampaignNumber': '19V435000'}]
# -------------------------------------------------------
# Recall data for: 1G1ZE5ST7GF315116 2016 CHEVROLET Malibu:
# [{'NHTSACampaignNumber': '16V125000'}, {'NHTSACampaignNumber': '16V084000'}, {'NHTSACampaignNumber': '16V151000'}, {'NHTSACampaignNumber': '16V272000'}, {'NHTSACampaignNumber': '16V502000'}, {'NHTSACampaignNumber': '16V781000'}, {'NHTSACampaignNumber': '18V358000'}, {'NHTSACampaignNumber': '18V400000'}]
# -------------------------------------------------------
# Recall data for: JHLRE48737C079032 2007 HONDA CR-V:
# [{'NHTSACampaignNumber': '11V395000'}, {'NHTSACampaignNumber': '16V061000'}, {'NHTSACampaignNumber': '16V346000'}, {'NHTSACampaignNumber': '17V030000'}, {'NHTSACampaignNumber': '17V545000'}, {'NHTSACampaignNumber': '17V417000'}, {'NHTSACampaignNumber': '18V268000'}, {'NHTSACampaignNumber': '18V268000'}, {'NHTSACampaignNumber': '19V182000'}, {'NHTSACampaignNumber': '19V182000'}, {'NHTSACampaignNumber': '19V378000'}, {'NHTSACampaignNumber': '19V500000'}, {'NHTSACampaignNumber': '19V502000'}]
# -------------------------------------------------------
# Recall data for: 3N1AB7AP5FL644997 2015 NISSAN Sentra:
# [{'NHTSACampaignNumber': '15V453000'}, {'NHTSACampaignNumber': '16V244000'}, {'NHTSACampaignNumber': '16V242000'}]
# -------------------------------------------------------
# Recall data for: 4S3BMCA63E3013977 2014 SUBARU Legacy:
# [{'NHTSACampaignNumber': '20V001000'}, {'NHTSACampaignNumber': '20V003000'}, {'NHTSACampaignNumber': '20V002000'}, {'NHTSACampaignNumber': '13V336000'}, {'NHTSACampaignNumber': '16V694000'}, {'NHTSACampaignNumber': '18V626000'}, {'NHTSACampaignNumber': '19V008000'}, {'NHTSACampaignNumber': '19V009000'}, {'NHTSACampaignNumber': '19V007000'}, {'NHTSACampaignNumber': '19V297000'}]
# -------------------------------------------------------
# Recall data for: 5NMSG73D68H228527 2008 HYUNDAI Santa Fe:
# [{'NHTSACampaignNumber': '08E016000'}, {'NHTSACampaignNumber': '08E055000'}, {'NHTSACampaignNumber': '08V272000'}, {'NHTSACampaignNumber': '11V472000'}, {'NHTSACampaignNumber': '12V354000'}, {'NHTSACampaignNumber': '13V113000'}]
# -------------------------------------------------------
# Recall data for: 1FMCU9GX0GUC00965 2016 FORD Escape:
# [{'NHTSACampaignNumber': '17V398000'}]
# -------------------------------------------------------
# Recall data for: 5NPEB4AC6DH542261 2013 HYUNDAI Sonata:
# [{'NHTSACampaignNumber': '20V121000'}, {'NHTSACampaignNumber': '12V352000'}, {'NHTSACampaignNumber': '14V434000'}, {'NHTSACampaignNumber': '17V226000'}, {'NHTSACampaignNumber': '17V152000'}, {'NHTSACampaignNumber': '17V617000'}, {'NHTSACampaignNumber': '18V137000'}, {'NHTSACampaignNumber': '18V934000'}]
# -------------------------------------------------------
# Recall data for: 1N4AL3AP1GC136385 2016 NISSAN Altima:
# [{'NHTSACampaignNumber': '16V244000'}, {'NHTSACampaignNumber': '17V040000'}, {'NHTSACampaignNumber': '18V915000'}]
# -------------------------------------------------------
# Recall data for: JF2SJGTCXHH489591 2017 SUBARU Forester:
# [{'NHTSACampaignNumber': '19V701000'}]
# -------------------------------------------------------
# Recall data for: 1G1PG5S9XB7309061 2011 CHEVROLET Cruze:
# [{'NHTSACampaignNumber': '11V221000'}, {'NHTSACampaignNumber': '11V270000'}, {'NHTSACampaignNumber': '11V273000'}, {'NHTSACampaignNumber': '12V288000'}, {'NHTSACampaignNumber': '12V289000'}, {'NHTSACampaignNumber': '13V360000'}, {'NHTSACampaignNumber': '16V502000'}]
# -------------------------------------------------------
# Recall data for: YV1612TK1G2390907 2016 VOLVO S60:
# [{'NHTSACampaignNumber': '15V555000'}, {'NHTSACampaignNumber': '16V798000'}, {'NHTSACampaignNumber': '19V849000'}]
# -------------------------------------------------------
# Recall data for: 2C3CDXCTXFH844233 2015 DODGE Charger:
# [{'NHTSACampaignNumber': '15V114000'}, {'NHTSACampaignNumber': '15V461000'}, {'NHTSACampaignNumber': '16V043000'}, {'NHTSACampaignNumber': '17V097000'}, {'NHTSACampaignNumber': '18E053000'}, {'NHTSACampaignNumber': '18V332000'}, {'NHTSACampaignNumber': '18V281000'}, {'NHTSACampaignNumber': '19V018000'}]
# -------------------------------------------------------
# Recall data for: 5FNRL18964B024706 2004 HONDA Odyssey:
# [{'NHTSACampaignNumber': '04V176000'}, {'NHTSACampaignNumber': '04V420000'}, {'NHTSACampaignNumber': '12V573000'}, {'NHTSACampaignNumber': '13V412000'}, {'NHTSACampaignNumber': '14V353000'}, {'NHTSACampaignNumber': '14V700000'}, {'NHTSACampaignNumber': '15V045000'}, {'NHTSACampaignNumber': '15V320000'}, {'NHTSACampaignNumber': '16V344000'}, {'NHTSACampaignNumber': '18V268000'}, {'NHTSACampaignNumber': '19V182000'}, {'NHTSACampaignNumber': '19V499000'}, {'NHTSACampaignNumber': '19V501000'}]
# -------------------------------------------------------
# Recall data for: JF1GV8J69BL510761 2011 SUBARU Impreza:
# [{'NHTSACampaignNumber': '20V002000'}, {'NHTSACampaignNumber': '20V001000'}, {'NHTSACampaignNumber': '20V003000'}, {'NHTSACampaignNumber': '14V311000'}, {'NHTSACampaignNumber': '14V830000'}, {'NHTSACampaignNumber': '16V358000'}, {'NHTSACampaignNumber': '17V014000'}, {'NHTSACampaignNumber': '16V738000'}, {'NHTSACampaignNumber': '18V012000'}, {'NHTSACampaignNumber': '19V008000'}, {'NHTSACampaignNumber': '19V009000'}, {'NHTSACampaignNumber': '19V007000'}, {'NHTSACampaignNumber': '19V149000'}, {'NHTSACampaignNumber': '19V297000'}]
# -------------------------------------------------------
# Recall data for: 1GCRCREC1FZ382906 2015 CHEVROLET Silverado:
# [{'NHTSACampaignNumber': '14V007000'}, {'NHTSACampaignNumber': '14V374000'}, {'NHTSACampaignNumber': '14V446000'}, {'NHTSACampaignNumber': '14V819000'}, {'NHTSACampaignNumber': '14V719000'}, {'NHTSACampaignNumber': '15V640000'}, {'NHTSACampaignNumber': '16V209000'}]
# -------------------------------------------------------
# Recall data for: 5J8TB18518A007012 2008 ACURA RDX:
# [{'NHTSACampaignNumber': '07V358000'}, {'NHTSACampaignNumber': '16V061000'}, {'NHTSACampaignNumber': '19V182000'}]
# -------------------------------------------------------
# Recall data for: 1HGCR2F11HA027908 2017 HONDA Accord:
# [{'NHTSACampaignNumber': '19V060000'}]
# -------------------------------------------------------
# -------------------------------------------------------
# JSON Decode error occurred for: 1d8hn44hx8b156429 2008 DODGE Caravan/Grand Caravan:
# -------------------------------------------------------
# Recall data for: 1G6DS5ED2B0127245 2011 CADILLAC CTS:
# [{'NHTSACampaignNumber': '14V341000'}, {'NHTSACampaignNumber': '14V394000'}]
# -------------------------------------------------------
# Recall data for: JTEDS41A082005043 2008 TOYOTA Highlander:
# [{'NHTSACampaignNumber': '08V181000'}, {'NHTSACampaignNumber': '09E022000'}, {'NHTSACampaignNumber': '09E028000'}, {'NHTSACampaignNumber': '09V223000'}, {'NHTSACampaignNumber': '10V023000'}, {'NHTSACampaignNumber': '10V036000'}, {'NHTSACampaignNumber': '10V035000'}, {'NHTSACampaignNumber': '11V245000'}, {'NHTSACampaignNumber': '12V491000'}, {'NHTSACampaignNumber': '14V168000'}, {'NHTSACampaignNumber': '14V743000'}, {'NHTSACampaignNumber': '15V689000'}, {'NHTSACampaignNumber': '16V396000'}]
# -------------------------------------------------------
# Recall data for: 1G1ZJ57B48F255289 2008 CHEVROLET Malibu:
# [{'NHTSACampaignNumber': '12V460000'}, {'NHTSACampaignNumber': '14E044000'}, {'NHTSACampaignNumber': '14V153000'}, {'NHTSACampaignNumber': '14V252000'}, {'NHTSACampaignNumber': '14V224000'}]
# -------------------------------------------------------
# Recall data for: 1FTRE14W25HA38075 2005 FORD E-150:
# [{'NHTSACampaignNumber': '06E056000'}, {'NHTSACampaignNumber': '09V102000'}, {'NHTSACampaignNumber': '09V100000'}, {'NHTSACampaignNumber': '11E047000'}]
# -------------------------------------------------------
# Recall data for: 1FT8W4DT4HEE82449 2017 FORD F-450:
# [{'NHTSACampaignNumber': '17V331000'}, {'NHTSACampaignNumber': '18V894000'}, {'NHTSACampaignNumber': '19V401000'}, {'NHTSACampaignNumber': '19V342000'}]
# -------------------------------------------------------
# Recall data for: 1C3CDFBB9GD661052 2016 DODGE Dart:
# [{'NHTSACampaignNumber': '16V113000'}, {'NHTSACampaignNumber': '16V813000'}, {'NHTSACampaignNumber': '17V824000'}, {'NHTSACampaignNumber': '19V293000'}]
# -------------------------------------------------------
# Recall data for: 5TFUU4EN7CX023014 2012 TOYOTA Tacoma:
# [{'NHTSACampaignNumber': '12V158000'}, {'NHTSACampaignNumber': '13V014000'}, {'NHTSACampaignNumber': '13V123000'}, {'NHTSACampaignNumber': '13V494000'}, {'NHTSACampaignNumber': '14V054000'}, {'NHTSACampaignNumber': '14V475000'}, {'NHTSACampaignNumber': '17V425000'}]
# -------------------------------------------------------
# Recall data for: 4S4BSACC2J3235364 2018 SUBARU Outback:
# [{'NHTSACampaignNumber': '18V935000'}, {'NHTSACampaignNumber': '18V773000'}]
# -------------------------------------------------------
# Recall data for: 1FTYR11U74TA18404 2004 FORD Ranger:
# [{'NHTSACampaignNumber': '04V331000'}, {'NHTSACampaignNumber': '06E065000'}, {'NHTSACampaignNumber': '09E025000'}, {'NHTSACampaignNumber': '11V352000'}, {'NHTSACampaignNumber': '15V322000'}, {'NHTSACampaignNumber': '16V036000'}, {'NHTSACampaignNumber': '17V787000'}, {'NHTSACampaignNumber': '17V788000'}]
# -------------------------------------------------------
# Recall data for: JF2SHADC2BH718070 2011 SUBARU Forester:
# [{'NHTSACampaignNumber': '20V003000'}, {'NHTSACampaignNumber': '20V002000'}, {'NHTSACampaignNumber': '20V001000'}, {'NHTSACampaignNumber': '12V099000'}, {'NHTSACampaignNumber': '12V602000'}, {'NHTSACampaignNumber': '14V311000'}, {'NHTSACampaignNumber': '14V830000'}, {'NHTSACampaignNumber': '16V358000'}, {'NHTSACampaignNumber': '16V738000'}, {'NHTSACampaignNumber': '17V014000'}, {'NHTSACampaignNumber': '18V012000'}, {'NHTSACampaignNumber': '19V008000'}, {'NHTSACampaignNumber': '19V009000'}, {'NHTSACampaignNumber': '19V007000'}, {'NHTSACampaignNumber': '19V297000'}]
# -------------------------------------------------------
# Recall data for: JTDKARFU5H3053629 2017 TOYOTA PRIUS:
# [{'NHTSACampaignNumber': '16V741000'}, {'NHTSACampaignNumber': '17V295000'}, {'NHTSACampaignNumber': '18V579000'}]
# -------------------------------------------------------
# Recall data for: 1GNKRJKDXDJ252253 2013 CHEVROLET Traverse:
# [{'NHTSACampaignNumber': '14V118000'}, {'NHTSACampaignNumber': '14V266000'}]
# -------------------------------------------------------
# Recall data for: 1N4AL3AP8GC188788 2016 NISSAN Altima:
# [{'NHTSACampaignNumber': '16V244000'}, {'NHTSACampaignNumber': '17V040000'}, {'NHTSACampaignNumber': '18V915000'}]
# -------------------------------------------------------
# Recall data for: 5NPE24AA1FH143100 2015 HYUNDAI Sonata:
# [{'NHTSACampaignNumber': '14V325000'}, {'NHTSACampaignNumber': '14V368000'}, {'NHTSACampaignNumber': '14V784000'}, {'NHTSACampaignNumber': '15V414000'}, {'NHTSACampaignNumber': '15V678000'}, {'NHTSACampaignNumber': '16V232000'}, {'NHTSACampaignNumber': '16V726000'}, {'NHTSACampaignNumber': '17V359000'}]
# -------------------------------------------------------
# Recall data for: JA4AT4AA8KZ003666 2019 MITSUBISHI ECLIPSE CROSS:
# [{'NHTSACampaignNumber': '18V620000'}]
# -------------------------------------------------------
# Recall data for: WAUFFAFL4FN046259 2015 AUDI A4:
# [{'NHTSACampaignNumber': '14V667000'}, {'NHTSACampaignNumber': '17V002000'}, {'NHTSACampaignNumber': '17V622000'}, {'NHTSACampaignNumber': '18V229000'}]
# -------------------------------------------------------
# Recall data for: 2FMDK4JC9DBA49130 2013 FORD Edge:
# [{'NHTSACampaignNumber': '14V002000'}, {'NHTSACampaignNumber': '14V393000'}]
# -------------------------------------------------------
# Recall data for: 3N1CN7AP7DL880337 2013 NISSAN Versa:
# [{'NHTSACampaignNumber': '15V507000'}]
# -------------------------------------------------------
# Recall data for: 1N4AL3AP0JC269470 2018 NISSAN Altima:
# [{'NHTSACampaignNumber': '19V654000'}]
# -------------------------------------------------------
# Recall data for: 1GKFK16347J179700 2007 GMC Yukon XL:
# [{'NHTSACampaignNumber': '08V441000'}, {'NHTSACampaignNumber': '10V240000'}]
# -------------------------------------------------------
# Recall data for: 1C4RJFJT3EC492884 2014 JEEP Grand Cherokee:
# [{'NHTSACampaignNumber': '13V289000'}, {'NHTSACampaignNumber': '13V483000'}, {'NHTSACampaignNumber': '14V154000'}, {'NHTSACampaignNumber': '14V293000'}, {'NHTSACampaignNumber': '14V391000'}, {'NHTSACampaignNumber': '14V636000'}, {'NHTSACampaignNumber': '14V634000'}, {'NHTSACampaignNumber': '14V643000'}, {'NHTSACampaignNumber': '15V461000'}, {'NHTSACampaignNumber': '16V240000'}, {'NHTSACampaignNumber': '17E061000'}, {'NHTSACampaignNumber': '17V435000'}, {'NHTSACampaignNumber': '17V741000'}, {'NHTSACampaignNumber': '17V572000'}, {'NHTSACampaignNumber': '18V332000'}]
# -------------------------------------------------------
# Recall data for: 1GKS2EEF3BR358029 2011 GMC Yukon:
# [{'NHTSACampaignNumber': '11V007000'}, {'NHTSACampaignNumber': '11V339000'}, {'NHTSACampaignNumber': '14V827000'}]
# -------------------------------------------------------
# Recall data for: 1HGES16384L008165 2004 HONDA Civic:
# [{'NHTSACampaignNumber': '04V550000'}, {'NHTSACampaignNumber': '06E023000'}, {'NHTSACampaignNumber': '06E032000'}, {'NHTSACampaignNumber': '06E064000'}, {'NHTSACampaignNumber': '07E104000'}, {'NHTSACampaignNumber': '07V512000'}, {'NHTSACampaignNumber': '09E025000'}, {'NHTSACampaignNumber': '14V353000'}, {'NHTSACampaignNumber': '14V700000'}, {'NHTSACampaignNumber': '15V370000'}, {'NHTSACampaignNumber': '15V320000'}, {'NHTSACampaignNumber': '18V268000'}, {'NHTSACampaignNumber': '19V182000'}, {'NHTSACampaignNumber': '19V499000'}, {'NHTSACampaignNumber': '19V501000'}]
# -------------------------------------------------------
# Recall data for: 3C4PDDGG5JT516842 2018 DODGE Journey:
# [{'NHTSACampaignNumber': '18V396000'}, {'NHTSACampaignNumber': '18V398000'}, {'NHTSACampaignNumber': '18V332000'}, {'NHTSACampaignNumber': '18V524000'}, {'NHTSACampaignNumber': '18V523000'}]
# -------------------------------------------------------
# Recall data for: WBA3F9C56EF484510 2014 BMW ActiveHybrid 3:
# [{'NHTSACampaignNumber': '15V189000'}, {'NHTSACampaignNumber': '15V520000'}]
# -------------------------------------------------------
# Recall data for: 3GNAXJEV6JL116387 2018 CHEVROLET Equinox:
# [{'NHTSACampaignNumber': '17V516000'}, {'NHTSACampaignNumber': '18V252000'}, {'NHTSACampaignNumber': '18V358000'}, {'NHTSACampaignNumber': '18V576000'}]
# -------------------------------------------------------
# Recall data for: 1G2ZJ57B094263057 2009 PONTIAC G6:
# [{'NHTSACampaignNumber': '09V073000'}, {'NHTSACampaignNumber': '12V460000'}, {'NHTSACampaignNumber': '14E044000'}, {'NHTSACampaignNumber': '14V153000'}, {'NHTSACampaignNumber': '14V252000'}]
# -------------------------------------------------------
# Recall data for: 1D7HE22K57S150625 2007 DODGE Dakota:
# [{'NHTSACampaignNumber': '06V341000'}, {'NHTSACampaignNumber': '14V795000'}, {'NHTSACampaignNumber': '15V313000'}, {'NHTSACampaignNumber': '16V352000'}]
# -------------------------------------------------------
# Recall data for: JA3AU26U59U036866 2009 MITSUBISHI Lancer:
# [{'NHTSACampaignNumber': '20V279000'}, {'NHTSACampaignNumber': '09V077000'}, {'NHTSACampaignNumber': '09V435000'}, {'NHTSACampaignNumber': '14V562000'}, {'NHTSACampaignNumber': '15V232000'}, {'NHTSACampaignNumber': '15V233000'}, {'NHTSACampaignNumber': '18V071000'}, {'NHTSACampaignNumber': '18V069000'}]
# -------------------------------------------------------
# Recall data for: 2D4FV48T65H661295 2005 DODGE Magnum:
# [{'NHTSACampaignNumber': '04V335000'}, {'NHTSACampaignNumber': '04V333000'}, {'NHTSACampaignNumber': '04V334000'}, {'NHTSACampaignNumber': '05V460000'}, {'NHTSACampaignNumber': '14V770000'}, {'NHTSACampaignNumber': '15V313000'}, {'NHTSACampaignNumber': '16V352000'}]
# -------------------------------------------------------
# Recall data for: 2C4RC1BGXCR228497 2012 CHRYSLER Town and Country:
# [{'NHTSACampaignNumber': '11V487000'}, {'NHTSACampaignNumber': '12V191000'}, {'NHTSACampaignNumber': '12V141000'}, {'NHTSACampaignNumber': '14V234000'}]
# -------------------------------------------------------
# Recall data for: 1GNSKBKC1FR577962 2015 CHEVROLET Tahoe:
# [{'NHTSACampaignNumber': '14V246000'}, {'NHTSACampaignNumber': '14V152000'}, {'NHTSACampaignNumber': '14V374000'}, {'NHTSACampaignNumber': '14V301000'}, {'NHTSACampaignNumber': '14V451000'}, {'NHTSACampaignNumber': '14V719000'}, {'NHTSACampaignNumber': '15V640000'}, {'NHTSACampaignNumber': '16V651000'}, {'NHTSACampaignNumber': '17V437000'}, {'NHTSACampaignNumber': '18V291000'}, {'NHTSACampaignNumber': '18V586000'}, {'NHTSACampaignNumber': '19V645000'}, {'NHTSACampaignNumber': '19V761000'}]
# -------------------------------------------------------
# Recall data for: 1J4GL38KX6W238970 2006 JEEP Liberty:
# [{'NHTSACampaignNumber': '05V460000'}, {'NHTSACampaignNumber': '06V036000'}, {'NHTSACampaignNumber': '06V072000'}, {'NHTSACampaignNumber': '06V288000'}, {'NHTSACampaignNumber': '07V089000'}, {'NHTSACampaignNumber': '09E039000'}, {'NHTSACampaignNumber': '12V085000'}, {'NHTSACampaignNumber': '13V252000'}, {'NHTSACampaignNumber': '15V222000'}, {'NHTSACampaignNumber': '18V278000'}]
# -------------------------------------------------------
# Recall data for: 1FTFW1CT0DKF14932 2013 FORD F-150:
# [{'NHTSACampaignNumber': '16V345000'}, {'NHTSACampaignNumber': '19V075000'}, {'NHTSACampaignNumber': '19V433000'}]
# -------------------------------------------------------
# Recall data for: 5XYPG4A37GG035004 2016 KIA Sorento:
# [{'NHTSACampaignNumber': '15V089000'}, {'NHTSACampaignNumber': '15V446000'}, {'NHTSACampaignNumber': '16V480000'}, {'NHTSACampaignNumber': '16V770000'}, {'NHTSACampaignNumber': '16V862000'}, {'NHTSACampaignNumber': '18V907000'}]
# -------------------------------------------------------
# Recall data for: 5NMSH73E29H264240 2009 HYUNDAI Santa Fe:
# [{'NHTSACampaignNumber': '11E040000'}, {'NHTSACampaignNumber': '12V354000'}, {'NHTSACampaignNumber': '13V113000'}]
# -------------------------------------------------------
# Recall data for: 1N4AL3AP9JC192503 2018 NISSAN Altima:
# [{'NHTSACampaignNumber': '19V654000'}]
# -------------------------------------------------------
# Recall data for: 1FTNX21L64EB84343 2004 FORD F-250:
# [{'NHTSACampaignNumber': '04V229000'}, {'NHTSACampaignNumber': '06E049000'}, {'NHTSACampaignNumber': '06E052000'}, {'NHTSACampaignNumber': '07E066000'}, {'NHTSACampaignNumber': '09E012000'}, {'NHTSACampaignNumber': '09E025000'}, {'NHTSACampaignNumber': '11V352000'}]
# -------------------------------------------------------
# Recall data for: 19uua66204a041062 2004 ACURA TL:
# [{'NHTSACampaignNumber': '04V176000'}, {'NHTSACampaignNumber': '08V091000'}, {'NHTSACampaignNumber': '08V092000'}, {'NHTSACampaignNumber': '11E022000'}, {'NHTSACampaignNumber': '19E068000'}, {'NHTSACampaignNumber': '19V182000'}]
# -------------------------------------------------------
